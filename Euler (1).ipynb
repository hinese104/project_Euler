# %% [markdown]
# ## P1

# %%
sum = 0

for x in range(1,1000):
    if x % 3 == 0 or x % 5 ==0:
        sum+=x

# %% [markdown]
# ## P2

# %%
import numpy as np
def gen_Fibonacci(upper_limit):
    nums = []
    nums.append(1)
    nums.append(2)
    while nums[-2]+nums[-1] <= upper_limit:
        nums.append(nums[-2]+nums[-1])
    return nums

nums = gen_Fibonacci(4e6)

sum = 0
for x in nums:
    if x % 2 == 0:
#         print(x)
        sum += x
sum
# Out:
# 4613732

# %% [markdown]
# ## P3

# %%
def ck_prime(num):
    x = 2
    while num % x != 0:
        x+=1
#     is_prime = any((num % np.array(range(2,num)))==0)==False ## Vectorized version (memory issue)
    return(x==num)

def find_max_prime(num):
    for x in range(2,600851475143+1):
#         if x % 10000 == 0:
#             print(x)
        if num % x == 0:
            if ck_prime(num / x):
                return(int(num / x))
        
find_max_prime(600851475143)
# Out:
# 6857

# %% [markdown]
# ## P64

# %%
import numpy as np
def next_set(N,b,c):
    """
    Helper function to get next set based on N, bn and cn
    For the special case of initialization, set b0 = np.floor(np.sqrt(N)) and c0 = 1
    """
    rt = np.floor(np.sqrt(N))
    c2 = (N - b**2)/c
    a2 = np.floor((b+rt)/c2)
    b2 = a2*c2 -b
    assert(c2.is_integer())
    return(int(a2),int(b2),int(c2))

def get_period(N):
    if np.sqrt(N).is_integer():
        return(0)
    else:
        a1,b1,c1 = next_set(N,np.floor(np.sqrt(N)),1)
        i=1
        an,bn,cn = next_set(N,b1,c1)
        while (an,bn,cn) != (a1,b1,c1):
            an,bn,cn = next_set(N,bn,cn)
            i+=1
        return(i)
    
store = []
for N in range(1,10001):
    if get_period(N) % 2 == 1:
        store.append(N)
print(len(store))
# Out:
# 1322

# %% [markdown]
# ## P252

# %%
import numpy as np
def rand_gen(N):
    """Generate randome numbers"""
    T = []
    Sn = 290797
    for n in range(N):
        Sn = Sn**2 % 50515093
        T.append((Sn % 2000) - 1000)
    return T
randoms = np.array(rand_gen(1000))
dots = randoms.reshape([-1,2])
print(dots[:2])
# Out:
# [[ 527  144]
#  [-488  732]]

# %%
def get_vector(dot1,dot2):
    """Get the vector between dot2 and dot1"""
    x = dot2[0]-dot1[0]
    y = dot2[1]-dot1[1]
    return([x,y])
    
def get_angle_area(v1,v2):
    """Get the angle between vector v2 and v1, ranging from [-180,180]"""
    v1_mag = np.linalg.norm(v1)
    v2_mag = np.linalg.norm(v2)
    
    cos_theta = np.dot(v1,v2)/v1_mag/v2_mag
    sin_theta = np.cross(v1,v2)/v1_mag/v2_mag
    if sin_theta >= 0:
        angle = np.rad2deg(np.arccos(cos_theta))
    else:
        angle = - np.rad2deg(np.arccos(cos_theta))
    area = np.cross(v1,v2).tolist()/2
    return(angle,area)

maxArea = 0

def max_area(acc_area):
    global maxArea
    maxArea = max(acc_area,maxArea)

# %%
def ck_convex(v1,v2,v3,v4):
    """check if the object is convex when adding a new dot"""
    convex = (get_angle_area(v1,v2)[0] >=0) and (get_angle_area(v2,v3)[0] > -1e-6) and (get_angle_area(v3,v4)[0] >=0)
    return(convex)

def ck_exclusive(v2,v3,v2_,v3_):
    """check if any dot falls into the new triangle"""
    exclusive = (get_angle_area(v2_,v3_)[0] >= 0) and (not ((get_angle_area(v2,v2_)[0] >=0) and (get_angle_area(v3,v3_)[0] <=0)))
    return(exclusive)
    
def add_one_dot(curr_list,new_dot,other_dots,acc_area):
    """add one dot to curr from candi and add the area of the new triangle into acc_ares"""
    v1 = get_vector(curr_list[-2],curr_list[-1])
    v2 = get_vector(curr_list[-1],new_dot)
    v3 = get_vector(new_dot,curr_list[0])
    v4 = get_vector(curr_list[0],curr_list[1])
    convex = ck_convex(v1,v2,v3,v4)
    exclusive = True
    if convex and other_dots != None:
        for x in other_dots:
            v2_ = get_vector(curr_list[-1],x)
            v3_ = get_vector(x,curr_list[0])
            exclusive = ck_exclusive(v2,v3,v2_,v3_)
            if not exclusive:
                break
    added = (convex and exclusive)
    if added:
        acc_area += get_angle_area(v2,v3)[1]
    return(added, acc_area)

def expand_convex_hole(curr_list,candi_dots,acc_area):
    if candi_dots != None:
        for x in candi_dots:
            other_dots = candi_dots.copy()
            other_dots.remove(x)
            added,acc_area = add_one_dot(curr_list,x,other_dots,acc_area)
            if added:
                next_list = curr_list.copy()
                next_list.append(x)  
                print(next_list,other_dots,acc_area)
                acc_area = expand_convex_hole(next_list,other_dots,acc_area) 
#                 print(acc_area)
                max_area(acc_area)
    return(acc_area)

# %%
maxArea = 0
# [[0.5,1.51]]

expand_convex_hole([[1,0],[1,1],[0.9,1]],[[0,-6]],0.05)

maxArea
# Out:
# [[1, 0], [1, 1], [0.9, 1], [0, -6]] [] 0.8499999999999999
# 0.8499999999999999

# %%
maxArea = 0
# [[0.5,1.51]]

expand_convex_hole([[1,0],[1,1]],[[0,2],[0,-1]],0)

maxArea
# maxArea
# Out:
# [[1, 0], [1, 1], [0, 2]] [[0, -1]] 0.5
# [[1, 0], [1, 1], [0, 2], [0, -1]] [] 2.0
# [[1, 0], [1, 1], [0, -1]] [[0, 2]] 2.5
# 2.5

# %%
maxArea = 0

dots_list = dots.tolist()
for x in dots_list:
    dots2 = dots_list.copy()
    dots2.remove(x)
    for y in dots2:
        dots3 = dots2.copy()
        dots3.remove(y)
        expand_convex_hole([x,y],dots3,0)
        print(maxArea)
        
maxArea
# Out:
# 0
# 0
# 0
# 0
# 0
# 0
# 0
# 0
# 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-327-e552248b0401> in <module>()
#       8         dots3 = dots2.copy()
#       9         dots3.remove(y)
# ---> 10         expand_convex_hole([x,y],dots3,0)
#      11         print(maxArea)
#      12
#
# <ipython-input-324-c1390aaf8333> in expand_convex_hole(curr_list, candi_dots, acc_area)
#      35             other_dots = candi_dots.copy()
#      36             other_dots.remove(x)
# ---> 37             added,acc_area = add_one_dot(curr_list,x,other_dots,acc_area)
#      38             if added:
#      39                 next_list = curr_list.copy()
#
# <ipython-input-324-c1390aaf8333> in add_one_dot(curr_list, new_dot, other_dots, acc_area)
#      21             v2_ = get_vector(curr_list[-1],x)
#      22             v3_ = get_vector(x,curr_list[0])
# ---> 23             exclusive = ck_exclusive(v2,v3,v2_,v3_)
#      24             if not exclusive:
#      25                 break
#
# <ipython-input-324-c1390aaf8333> in ck_exclusive(v2, v3, v2_, v3_)
#       6 def ck_exclusive(v2,v3,v2_,v3_):
#       7     """check if any dot falls into the new triangle"""
# ----> 8     exclusive = (get_angle_area(v2_,v3_)[0] >= 0) and (not ((get_angle_area(v2,v2_)[0] >=0) and (get_angle_area(v3,v3_)[0] <=0)))
#       9     return(exclusive)
#      10
#
# <ipython-input-210-ba0220c0a4b3> in get_angle_area(v1, v2)
#      10     v2_mag = np.linalg.norm(v2)
#      11
# ---> 12     cos_theta = np.dot(v1,v2)/v1_mag/v2_mag
#      13     sin_theta = np.cross(v1,v2)/v1_mag/v2_mag
#      14     if sin_theta >= 0:
#
# KeyboardInterrupt:

# %%
dots
# Out:
# array([[ 527,  144],
#        [-488,  732],
#        [-454, -947],
#        [-883,  -38],
#        [-754,   70],
#        [-178,  540],
#        [  54,  316],
#        [-389,  938],
#        [ 913, -860],
#        [ 806,  528],
#        [ 331,  698],
#        [ -60,  138],
#        [-811,  286],
#        [-646, -422],
#        [-665, -726],
#        [ 491,  368],
#        [-827, -607],
#        [-893, -826],
#        [-477,  -23],
#        [ 273, -175],
#        [-212,  817],
#        [-278,  293],
#        [-188,  969],
#        [-922,  255],
#        [-373, -412],
#        [ 708,  670],
#        [-526, -246],
#        [ 343, -756],
#        [-370, -526],
#        [-930,  111],
#        [-151,  786],
#        [-138,  754],
#        [-129,  413],
#        [-421,  177],
#        [-737, -215],
#        [-436,  263],
#        [ 357, -863],
#        [-950,  338],
#        [-189,  143],
#        [ 128, -889],
#        [ 530, -269],
#        [ 429,  926],
#        [-323,  891],
#        [ 230, -222],
#        [ 454,   12],
#        [ 734,  203],
#        [  43,  223],
#        [ 836,  939],
#        [ 741, -577],
#        [-768, -850],
#        [ 250, -554],
#        [-879,  206],
#        [-941, -333],
#        [ 521, -475],
#        [  43, -212],
#        [-855, -388],
#        [ 494,  130],
#        [ 546,  680],
#        [ 530,  381],
#        [-304,  127],
#        [ 348, -318],
#        [-779,  757],
#        [  56, -429],
#        [-319, -349],
#        [  92,  155],
#        [ -87,  386],
#        [ 514,  463],
#        [ 699,   72],
#        [ 120,  410],
#        [ 144,  655],
#        [-808,  222],
#        [ 327,  394],
#        [ 863, -835],
#        [  55,   -9],
#        [-921, -333],
#        [ 149, -331],
#        [-313,  997],
#        [ 528, -412],
#        [ 694, -315],
#        [ -69, -499],
#        [ 752,   85],
#        [-272,  270],
#        [ 700, -966],
#        [ 748,  876],
#        [ 283, -331],
#        [ 944,  225],
#        [ 129,  498],
#        [-669, -613],
#        [ 746,  140],
#        [-488,  303],
#        [-277, -153],
#        [-689,  207],
#        [ 645, -599],
#        [  66,  441],
#        [-746,  194],
#        [ 876, -701],
#        [-529,  490],
#        [ 846,  830],
#        [ 130,  542],
#        [-994,   15],
#        [-408,  525],
#        [ 518, -420],
#        [-589, -536],
#        [-884,  920],
#        [-841, -332],
#        [  -1,  901],
#        [ 948, -879],
#        [  78,  621],
#        [ 168,  827],
#        [ 941,   77],
#        [-683,  831],
#        [ 657,  734],
#        [-571, -847],
#        [  57, -105],
#        [-153, -676],
#        [ 139, -214],
#        [ 728,   39],
#        [ -22, -503],
#        [ 532,  288],
#        [ 567,  -49],
#        [ 854, -758],
#        [ 743, -402],
#        [ 669, -621],
#        [  75, -478],
#        [-651,  420],
#        [ 689,  963],
#        [-582,  974],
#        [-863,  745],
#        [-449,  682],
#        [ 389, -946],
#        [-544,  808],
#        [-599,  798],
#        [-470,   93],
#        [ 253, -141],
#        [ 489,  283],
#        [-920, -871],
#        [ 212, -331],
#        [ 601,  598],
#        [ 861,  204],
#        [-918, -379],
#        [-963,  679],
#        [-783,  169],
#        [ 720, -780],
#        [ 417, -604],
#        [ 595,   70],
#        [ 748, -688],
#        [  63,  698],
#        [-993, -568],
#        [-636,  184],
#        [-529,  262],
#        [ 987,  927],
#        [-758, -396],
#        [-954,  366],
#        [-586, -365],
#        [-228, -159],
#        [ 762, -104],
#        [  57,  713],
#        [-712, -102],
#        [ 355, -580],
#        [-493,  178],
#        [-783,  774],
#        [ -52,  -17],
#        [-713,  617],
#        [ 534,  332],
#        [ 862,  821],
#        [ 928,  719],
#        [ 963, -429],
#        [-633, -533],
#        [-960,   35],
#        [  27,  544],
#        [-603, -758],
#        [-970, -602],
#        [ 767,  845],
#        [-398, -133],
#        [-702,  283],
#        [-496,  570],
#        [-174,   12],
#        [ 855,  593],
#        [ 235,  264],
#        [ 410,  849],
#        [-108,    0],
#        [-560, -912],
#        [ 990,  896],
#        [ 468, -250],
#        [-548, -511],
#        [-291, -917],
#        [ -91,  810],
#        [-829,  975],
#        [ 222, -239],
#        [-646,  783],
#        [ 612,  633],
#        [-133,  464],
#        [-854, -420],
#        [ 888,  112],
#        [-900, -185],
#        [ 291,  558],
#        [-342,  707],
#        [ 409,  736],
#        [ 256,  758],
#        [-358, -479],
#        [ 768,  231],
#        [  33,  802],
#        [ 372, -125],
#        [ 555,  164],
#        [ 433,  925],
#        [-776, -558],
#        [-397,  106],
#        [ 184, -258],
#        [-783,  846],
#        [-465,  -16],
#        [-935,  435],
#        [-293,  263],
#        [ 812,  286],
#        [-397, -160],
#        [-957, -926],
#        [-393, -388],
#        [  66, -481],
#        [ -22,  420],
#        [-350,  345],
#        [-228,  816],
#        [-885,  509],
#        [ 213, -373],
#        [ 158,  372],
#        [ 860,  438],
#        [-631,  424],
#        [ 254, -164],
#        [-327,  328],
#        [ 828, -517],
#        [ 644, -630],
#        [-746, -161],
#        [ 849, -687],
#        [-401, -720],
#        [ 218,  940],
#        [-901,  253],
#        [ 604, -603],
#        [-687,  301],
#        [-147, -691],
#        [   6, -556],
#        [ 766, -548],
#        [ 448,  259],
#        [ 850,   48],
#        [-613,   38],
#        [-756,  323],
#        [ 363,  466],
#        [ 687,   35],
#        [ 878,  251],
#        [ 929,  780],
#        [ 890, -574],
#        [ 190, -523],
#        [-805, -825],
#        [ 369,  714],
#        [ 366, -498],
#        [-992, -115],
#        [-371,  158],
#        [  75, -982],
#        [ 892,  681],
#        [ 540,  628],
#        [-418, -144],
#        [-281,  399],
#        [-871,  638],
#        [-720, -734],
#        [-311, -145],
#        [-679, -826],
#        [ 882, -594],
#        [ 938, -426],
#        [ 460, -519],
#        [ -92, -567],
#        [-786,  242],
#        [ 628, -553],
#        [ 817,  -69],
#        [-241,  213],
#        [ 287, -150],
#        [-677, -167],
#        [ 436,  970],
#        [-992,   18],
#        [ 599,  800],
#        [-105,  569],
#        [ 843, -172],
#        [-342,  329],
#        [-305,  192],
#        [ 602,   91],
#        [-668, -719],
#        [  24, -966],
#        [ 269,  -77],
#        [ 207,  353],
#        [ 600,  110],
#        [ 254, -866],
#        [ 116,  -21],
#        [ 894,  487],
#        [-192,  869],
#        [-938,  750],
#        [-173, -691],
#        [-721,  691],
#        [ 691,  828],
#        [-813, -757],
#        [ 784,  359],
#        [-553,  900],
#        [ 156, -272],
#        [ 791,  537],
#        [-146,  382],
#        [-654,  839],
#        [  -3,  705],
#        [ -65, -476],
#        [ 242,  142],
#        [ 143,  983],
#        [ 804, -415],
#        [  68,  513],
#        [-239, -272],
#        [ 842, -934],
#        [-139, -665],
#        [  33, -385],
#        [ 668,  973],
#        [  37, -441],
#        [-464, -984],
#        [ 693,   22],
#        [-864, -841],
#        [ 242,  711],
#        [ 272, -577],
#        [ 700, -933],
#        [ 750,  -42],
#        [-601,  159],
#        [ 809,   49],
#        [-282,  671],
#        [-610, -275],
#        [-730,  141],
#        [-557,  262],
#        [ 533, -946],
#        [-806, -917],
#        [-644, -686],
#        [-985,  339],
#        [-671,  300],
#        [ 680, -401],
#        [ -28, -781],
#        [ 650,   47],
#        [ 328,  808],
#        [-381,  -36],
#        [-268,  980],
#        [ 385,  613],
#        [-210, -969],
#        [-946,  780],
#        [ 649, -501],
#        [ -75,  -61],
#        [ 842,  974],
#        [  21, -252],
#        [ 348, -556],
#        [ 735,   32],
#        [   9, -426],
#        [ 956,  698],
#        [  91,  335],
#        [ 423,  558],
#        [ 453,  267],
#        [ 611, -210],
#        [-969,  810],
#        [-334,  168],
#        [ 811, -552],
#        [-502, -337],
#        [ 306, -615],
#        [ 532, -873],
#        [ 951, -960],
#        [-517,   74],
#        [ 839,  296],
#        [-461, -746],
#        [-277,  322],
#        [-576,  108],
#        [ 633,  213],
#        [-676,  419],
#        [ 264,  921],
#        [ 279,  758],
#        [ 763, -103],
#        [ 244, -476],
#        [-158,  213],
#        [ 576, -145],
#        [  95,  946],
#        [ 512,  250],
#        [-666,   63],
#        [  88, -745],
#        [  46, -971],
#        [ 605, -147],
#        [ 918,  833],
#        [ 537,  -80],
#        [ 330,  670],
#        [-418,  359],
#        [-755, -273],
#        [ 652, -116],
#        [ 105, -711],
#        [-471,  737],
#        [-394, -912],
#        [ -36,  652],
#        [ -85,  338],
#        [-476, -535],
#        [ -14, -163],
#        [-746,  412],
#        [-653, -782],
#        [  35,  707],
#        [  19,  754],
#        [-449, -463],
#        [-218, -878],
#        [-484,  265],
#        [-406,  228],
#        [ 280,  951],
#        [ 964, -726],
#        [-209,  -24],
#        [-702, -680],
#        [-617, -749],
#        [ 682, -944],
#        [-838,  -76],
#        [ 811, -400],
#        [ 984,  178],
#        [  17,  553],
#        [-812,  786],
#        [ 192, -500],
#        [-860,  288],
#        [ 781, -210],
#        [ 960, -166],
#        [ 615,  876],
#        [-248, -473],
#        [ -79, -401],
#        [  23, -970],
#        [ 953,  -30],
#        [-330, -809],
#        [  91,  663],
#        [ 156,  502],
#        [-197, -565],
#        [-264,  952],
#        [-740,  -95],
#        [ 171, -517],
#        [-624,  675],
#        [-539, -206],
#        [-614,  142],
#        [ 935, -595],
#        [ 103, -972],
#        [ -46, -897],
#        [-508, -934],
#        [ 554, -555],
#        [-261, -586],
#        [ -51,  366],
#        [-854, -239],
#        [-572, -669],
#        [ 493,  443],
#        [ 165,  536],
#        [ 925,  -10],
#        [-928, -664],
#        [ -43,   94],
#        [  87,  870],
#        [ 472,  378],
#        [-151, -923],
#        [-185,  363],
#        [-480,  405],
#        [-660,  350],
#        [ 614,  335],
#        [-344, -636],
#        [-848, -477],
#        [ 273, -245],
#        [-345, -421],
#        [-479, -645],
#        [ 697, -639],
#        [ -10,  913],
#        [ 386,  757],
#        [ 741,  158],
#        [-797, -554],
#        [ 910,  735],
#        [-850,   56],
#        [ 657, -380],
#        [-286, -607],
#        [ -95,  380],
#        [ 347,  927],
#        [ 329,  894],
#        [-305,  569],
#        [ -57, -419],
#        [-528,   52],
#        [-456, -441],
#        [ 222, -659],
#        [-788,  429],
#        [ 423,  185],
#        [-306, -447],
#        [ 754,  295],
#        [-707,   52],
#        [ 894,  610],
#        [-717, -389],
#        [ 458,  355],
#        [ 223, -112],
#        [-453, -935],
#        [-563,  810],
#        [-952,  669],
#        [ 431, -961],
#        [ 844,  255],
#        [-181,   65],
#        [-210,  943],
#        [ 408, -419],
#        [ -60,  898],
#        [ 677,  669],
#        [  80,  -24],
#        [ 265,  314],
#        [-175, -112],
#        [ -23,    2],
#        [ 506,  829],
#        [-527,   54],
#        [-911,  692],
#        [-586, -967],
#        [ 683, -433]])

# %%
maxArea = 0
dotsList = dots.tolist()
expand_convex_hole(dotsList[:2],dotsList[2:8],0)
maxArea
# Out:
# 0

# %%
# Out:
# 0

# %%
v1 = get_vector(dots[0],dots[1])
v2 = get_vector(dots[1],dots[2])
print(v1,v2)
print(np.dot(v1,v2))
print(np.cross(v1,v2))
# Out:
# [-1015, 588] [34, -1679]
# -1021762
# 1684193
